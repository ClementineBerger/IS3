# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os

from IPython.display import display, Audio

import librosa

# %%
parent_data_folder = os.path.join(
    os.environ['AUDIBLE_DATA'],
    "rendering",
    "datasets",
)

# parent_data_folder = os.environ['MY_DATA']

metadata_path = os.path.join(
    parent_data_folder,
    "impulsive_sound_rejection",
    "synthetic_stationary_background",
    "metadata.csv"
)

# %%
# Load the metadata, opening dataframe

metadata = pd.read_csv(metadata_path)
display(metadata)
# Out:
#                      label  duration  \
# 0     synthetic_stationary      10.0
# 1     synthetic_stationary      10.0
# 2     synthetic_stationary      10.0
# 3     synthetic_stationary      10.0
# 4     synthetic_stationary      10.0
# ...                    ...       ...
# 1495  synthetic_stationary      10.0
# 1496  synthetic_stationary      10.0
# 1497  synthetic_stationary      10.0
# 1498  synthetic_stationary      10.0
# 1499  synthetic_stationary      10.0
#
#                                               file_path
# 0     impulsive_sound_rejection/synthetic_stationary...
# 1     impulsive_sound_rejection/synthetic_stationary...
# 2     impulsive_sound_rejection/synthetic_stationary...
# 3     impulsive_sound_rejection/synthetic_stationary...
# 4     impulsive_sound_rejection/synthetic_stationary...
# ...                                                 ...
# 1495  impulsive_sound_rejection/synthetic_stationary...
# 1496  impulsive_sound_rejection/synthetic_stationary...
# 1497  impulsive_sound_rejection/synthetic_stationary...
# 1498  impulsive_sound_rejection/synthetic_stationary...
# 1499  impulsive_sound_rejection/synthetic_stationary...
#
# [1500 rows x 3 columns]

# %%
idx = np.random.randint(0, len(metadata))
file_path = os.path.join(parent_data_folder, metadata.iloc[idx]['file_path'])

print(file_path)

signal, sr = librosa.load(file_path, sr=None)
print(sr)
# Out:
# /home/admin/mnt/tsi/audiosig/audible/rendering/datasets/impulsive_sound_rejection/synthetic_stationary_background/audio/background_1270.wav
# 44100

# %%
plt.figure(figsize=(10, 5))
t = np.arange(len(signal)) / sr
plt.plot(t, signal)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Signal')
plt.grid()
plt.show()

display(Audio(signal, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
